# %%
import json
import pickle
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import OneHotEncoder

# %%
from sklearn.datasets import load_iris
dataset = load_iris()

# %%
dataset['DESCR']
# Out:
# '.. _iris_dataset:\n\nIris plants dataset\n--------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 150 (50 in each of three classes)\n    :Number of Attributes: 4 numeric, predictive attributes and the class\n    :Attribute Information:\n        - sepal length in cm\n        - sepal width in cm\n        - petal length in cm\n        - petal width in cm\n        - class:\n                - Iris-Setosa\n                - Iris-Versicolour\n                - Iris-Virginica\n                \n    :Summary Statistics:\n\n    ============== ==== ==== ======= ===== ====================\n                    Min  Max   Mean    SD   Class Correlation\n    ============== ==== ==== ======= ===== ====================\n    sepal length:   4.3  7.9   5.84   0.83    0.7826\n    sepal width:    2.0  4.4   3.05   0.43   -0.4194\n    petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)\n    petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)\n    ============== ====
# ...

# %%
print('The fields given have the following ranges: ')

print(dataset['feature_names'][0] + ':', data['x'][:, 0].max(), data['x'][:, 0].min())
print(dataset['feature_names'][1] + ' :', data['x'][:, 1].max(), data['x'][:, 1].min())
print(dataset['feature_names'][2] + ':', data['x'][:, 2].max(), data['x'][:, 2].min())
print(dataset['feature_names'][3] + ' :', data['x'][:, 3].max(), data['x'][:, 3].min())
# Out:
# The fields given have the following ranges:
# sepal length (cm): 7.9 4.3
# sepal width (cm) : 4.4 2.0
# petal length (cm): 6.9 1.0
# petal width (cm) : 2.5 0.1

# %%
def train_model(dataset):
    
    data={}
    data['x'] = dataset['data']
    data['y'] = dataset['target']
    
    data['y'] = OneHotEncoder(sparse=False).fit_transform(data['y'].reshape(-1, 1))
    
    model = None
    model = keras.Sequential([
        keras.layers.Dense(4, activation='sigmoid', input_shape=(4,)),
        keras.layers.Dense(4, activation='sigmoid'),
        keras.layers.Dense(3, activation='softmax')
    ])
    
    model.compile(optimizer='adam',
                  loss='categorical_crossentropy', 
                  metrics=['accuracy']
             )
    
    model.fit(data['x'], data['y'], epochs=500, batch_size=5)
    
    return model

# %%
model=train_model(dataset)
# Out:
# Epoch 1/500
# 30/30 [==============================] - 0s 1ms/step - loss: 1.1084 - accuracy: 0.5000
# Epoch 2/500
# 30/30 [==============================] - 0s 1ms/step - loss: 1.1026 - accuracy: 0.6533
# Epoch 3/500
# 30/30 [==============================] - 0s 1ms/step - loss: 1.0993 - accuracy: 0.3867
# Epoch 4/500
# 30/30 [==============================] - 0s 1ms/step - loss: 1.0956 - accuracy: 0.4000
# Epoch 5/500
# 30/30 [==============================] - 0s 1ms/step - loss: 1.0937 - accuracy: 0.5933
# Epoch 6/500
# 30/30 [==============================] - 0s 1ms/step - loss: 1.0901 - accuracy: 0.6600
# Epoch 7/500
# 30/30 [==============================] - 0s 1ms/step - loss: 1.0879 - accuracy: 0.6667
# Epoch 8/500
# 30/30 [==============================] - 0s 1ms/step - loss: 1.0861 - accuracy: 0.6667
# Epoch 9/500
# 30/30 [==============================] - 0s 1ms/step - loss: 1.0834 - accuracy: 0.6667
# Epoch 10/500
# ...

# %%
import tensorflowjs as tfjs
model.save('./iris_nn_model')
tfjs.converters.save_keras_model(model, './iris_nn_model_js')
# Out:
# INFO:tensorflow:Assets written to: ./iris_nn_model/assets
# /home/shashankmoghe/.local/lib/python3.8/site-packages/tensorflowjs/converters/keras_h5_conversion.py:122: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   return h5py.File(h5file)
